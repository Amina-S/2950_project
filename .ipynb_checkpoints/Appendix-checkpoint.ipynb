# %% [markdown]
# # Appendix: Data Collection and Cleaning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None

# %% [markdown]
# We primarily use web scraping to acquire data and store it in two tables.
#
# ## piazza.com
# * See "piazza_data_collect.ipynb"
# * Every course on Piazza has a stats report accessible to anyone enrolled in the class (under the statistics tab). A few courses do not have this report because there was not enough piazza activity.
# * We compiled a list of courses (with no duplicates) from various departments taught in various semesters that used piazza.com as an interactive platform. For each of these courses, we recorded the URL for its stats page in the file "piazza_stats.txt". Here we also manually added the semester corresponding to each stats report. We then iterated through each of the URLs in the file and recorded in [ piazza .csv ] various attributes for each course:

# %%
piazza_data = pd.read_csv('piazza.csv')
piazza_data
# Out:
#                   Course#                  Professor  Total_Q %Response  \
# 0           PHYS 2213 S19         Alan Giambattista       473      100%
# 1               MATH 2930              Alan Zehnder       390       99%
# 2               MATH 1920             Reyer Sjamaar       323      100%
# 3              ENGRD 2700               Yudong Chen       200       99%
# 4          ECE/ENGRI 1210            David Albonesi       341      100%
# 5                 CS 3220                Anil Damle        83       95%
# 6                 CS 2800            Michael George      1198       97%
# 7                 CS 2110                Anne Bracy      1231      100%
# 8                 CS 2850              David Easley       844       97%
# 9               MATH 2930             Alex Townsend       745       98%
# 10              PHYS 2218             Andre Leclair       117       99%
# 11              MATH 2940              Adrian Lewis       696       97%
# 12                CS 4700                Haym Hirsh       409       99%
# 13                CS 2110               David Gries      2147      100%
# 14                CS 2043           Ronald Dinapoli       203      100%
# 15                CS 1110              Walker White      3825      100%
# 16               ECE 3140             Jose Martinez      1277       90%
# 17              CHEM 2510          Thomas Ruttledge       426       99%
# 18                CS 1110              Walker White      3825      100%
# 19                CS 2110               David Gries      1524      100%
# 20              MATH 2940             Alex Townsend       696       97%
# 21          PHYS 2213 F19              Ivan Bazarov       472      100%
# 22                CS 1110                 Daisy Fan       336      100%
# 23             ENGRD 2700              Jamol Pender       136       99%
# 24              MATH 2930              Alan Zehnder       173       98%
# 25              PHYS 1116           Liam McAllister        46       83%
# 26                CS 4120              Andrew Myers       433       98%
# 27                CS 3410                Anne Bracy      1167      100%
# 28                CS 2112              Andrew Myers       694      100%
# 29                CS 2110               David Gries      2216      100%
# 30                CS 2800            Michael George      1554       96%
# 31              MATH 2940          Katya Scheinberg       583       97%
# 32          PHYS 2213 F19              Ivan Bazarov       472      100%
# 33               MAE 2030              Richard Rand       193       90%
# 34              MATH 2930                Hadas Ritz       616       99%
# 35  PHYS 2213 Spring 2020         Alan Giambattista       375      100%
# 36             ENGRI 1140  Christopher "Kit" Umbach       209       93%
# 37         ECE/ENGRD 2720              Aaron Wagner       217       97%
# 38                CS 2800            Michael George      1101       96%
# 39     ECE 2100/ENGRD2100          Clifford Pollock       141       97%
# 40               ECE 2200           David Delchamps       243       99%
# 41              MATH 2930           Steven Strogatz       429       97%
# 42                CS 3410        Hakim Weatherspoon      2224      100%
# 43          INFO/STS 4240            Phoebe Sengers       349      100%
# 44                CS 1110              Walker White      2681      100%
# 45                CS 2110               David Gries      2036      100%
# 46                CS 2800            Michael George      1058      100%
#
#     #Contributions  Avg_Response_Time  Enrolled instructor_response %Active  \
# 0             1895                 22       259                 63%     47%
# 1             1398                 39       417                 74%     43%
# 2             1281                 49       543                 74%     31%
# 3              546                 40       162                 88%     50%
# 4             1204                 26       135                 90%     58%
# 5              252                 24        37                 94%     73%
# 6             4700                 20       419                 85%     60%
# 7             5196                  9       618                 86%     57%
# 8             2799                 39       506                 69%     61%
# 9             3158                 40       430                 70%     54%
# 10             587                  7        28                 68%     75%
# 11            2527                 44       482                 71%     47%
# 12            1875                 22       238                 96%     55%
# 13           11442                  3       721                 91%     58%
# 14             906                 22       145                 94%     60%
# 15           11364                 10       716                 97%     69%
# 16            4580                 64       216                 70%    100%
# 17            1665                 52       379                 77%     42%
# 18           11364                 10       716                 97%     69%
# 19            5754                  4       590                 74%     57%
# 20            2527                 44       482                 71%     47%
# 21            2433                 11       404                 79%     51%
# 22            1559                 20       405                 90%     43%
# 23             387                 41        42                 91%     83%
# 24             558                 25        36                 92%     89%
# 25             195                 44        44                 43%     32%
# 26            1678                 40        84                 83%     73%
# 27            4743                 16       197                 84%     87%
# 28            2912                  8        90                 83%     89%
# 29           14115                  1       667                 99%     69%
# 30            4808                 37       396                 85%     72%
# 31            2692                 16       473                 52%     53%
# 32            2433                 11       404                 79%     51%
# 33             765                 38       145                 75%     57%
# 34            2029                 43       403                 64%     47%
# 35            1842                 14       242                 78%     57%
# 36             635                136        58                 54%     84%
# 37             673                 45        61                 87%     84%
# 38            4073                 17       424                 78%     66%
# 39             536                 83        56                 89%     59%
# 40             963                 11        80                 94%     68%
# 41            1658                 54       410                 59%     43%
# 42            8598                 11       205                 87%     90%
# 43            1246                 20       201                 95%     68%
# 44            8544                 15       569                 84%     73%
# 45           12742                  6       662                 90%     61%
# 46            6008                  9       417                 77%     63%
#
#    semester
# 0      SP19
# 1      SP20
# 2      FA18
# 3      FA19
# 4      SP19
# 5      FA19
# 6      SP19
# 7      FA18
# 8      FA19
# 9      FA18
# 10     SP19
# 11     SP19
# 12     SP20
# 13     SP19
# 14     SP20
# 15     FA18
# 16     SP19
# 17     SP20
# 18     FA18
# 19     FA19
# 20     FA19
# 21     FA19
# 22     SP20
# 23     SP20
# 24     SP20
# 25     SP19
# 26     SP20
# 27     FA18
# 28     FA19
# 29     SP20
# 30     SP20
# 31     SP20
# 32     FA19
# 33     SP20
# 34     SP19
# 35     SP20
# 36     FA18
# 37     FA19
# 38     FA19
# 39     SP20
# 40     SP20
# 41     FA19
# 42     SP19
# 43     FA18
# 44     FA17
# 45     SP18
# 46     FA18

# %% [markdown]
# **Cleaning**
# * As of now, some of our piazza stats course names are irregular. Because there is only a small number of these irregularities and they don't follow any particular pattern, we chose to manually fix each one
# * We also need to get rid of the '%' following the values in columns "% response" and "instructor_response"
# * We also want to be able to group our courses by departments

# %%
#manually rename some courses
piazza_data['Course#'][0] = 'PHYS 2213'
piazza_data['Course#'][4] = 'ECE 1210'
piazza_data['Course#'][3] = 'ORIE 2700'
piazza_data['Course#'][21] = 'PHYS 2213'
piazza_data['Course#'][23] = 'ORIE 2700'
piazza_data['Course#'][32] = 'PHYS 2213'
piazza_data['Course#'][35] = 'PHYS 2213'
piazza_data['Course#'][37] = 'ECE 2720'
piazza_data['Course#'][39] = 'ECE 2100'
piazza_data['Course#'][43] = 'INFO 4240'

#convert columns into appropriate data types, clean % symbols
piazza_data['%Response'] = (piazza_data['%Response'].str.slice(stop=-1)).astype(int)
piazza_data['instructor_response'] = (piazza_data['instructor_response'].str.slice(stop=-1)).astype(int)
piazza_data['%Active'] = (piazza_data['%Active'].str.slice(stop=-1)).astype(int)
piazza_data['Avg_Response_Time'] = (piazza_data['Avg_Response_Time']).astype(int)
piazza_data['Total_Q'] = (piazza_data['Total_Q']).astype(int)
piazza_data['Enrolled'] = (piazza_data['Enrolled']).astype(int)
piazza_data['#Contributions'] = (piazza_data['#Contributions']).astype(int)

#create more descriptive columns from full course names
piazza_data['department'] = (piazza_data['Course#'].str.split(expand=True))[0]
piazza_data['course_num'] = (piazza_data['Course#'].str.split(expand=True))[1]
 
piazza_data
# Out:
#        Course#                  Professor  Total_Q  %Response  #Contributions  \
# 0    PHYS 2213         Alan Giambattista       473        100            1895
# 1    MATH 2930              Alan Zehnder       390         99            1398
# 2    MATH 1920             Reyer Sjamaar       323        100            1281
# 3    ORIE 2700               Yudong Chen       200         99             546
# 4     ECE 1210            David Albonesi       341        100            1204
# 5      CS 3220                Anil Damle        83         95             252
# 6      CS 2800            Michael George      1198         97            4700
# 7      CS 2110                Anne Bracy      1231        100            5196
# 8      CS 2850              David Easley       844         97            2799
# 9    MATH 2930             Alex Townsend       745         98            3158
# 10   PHYS 2218             Andre Leclair       117         99             587
# 11   MATH 2940              Adrian Lewis       696         97            2527
# 12     CS 4700                Haym Hirsh       409         99            1875
# 13     CS 2110               David Gries      2147        100           11442
# 14     CS 2043           Ronald Dinapoli       203        100             906
# 15     CS 1110              Walker White      3825        100           11364
# 16    ECE 3140             Jose Martinez      1277         90            4580
# 17   CHEM 2510          Thomas Ruttledge       426         99            1665
# 18     CS 1110              Walker White      3825        100           11364
# 19     CS 2110               David Gries      1524        100            5754
# 20   MATH 2940             Alex Townsend       696         97            2527
# 21   PHYS 2213              Ivan Bazarov       472        100            2433
# 22     CS 1110                 Daisy Fan       336        100            1559
# 23   ORIE 2700              Jamol Pender       136         99             387
# 24   MATH 2930              Alan Zehnder       173         98             558
# 25   PHYS 1116           Liam McAllister        46         83             195
# 26     CS 4120              Andrew Myers       433         98            1678
# 27     CS 3410                Anne Bracy      1167        100            4743
# 28     CS 2112              Andrew Myers       694        100            2912
# 29     CS 2110               David Gries      2216        100           14115
# 30     CS 2800            Michael George      1554         96            4808
# 31   MATH 2940          Katya Scheinberg       583         97            2692
# 32   PHYS 2213              Ivan Bazarov       472        100            2433
# 33    MAE 2030              Richard Rand       193         90             765
# 34   MATH 2930                Hadas Ritz       616         99            2029
# 35   PHYS 2213         Alan Giambattista       375        100            1842
# 36  ENGRI 1140  Christopher "Kit" Umbach       209         93             635
# 37    ECE 2720              Aaron Wagner       217         97             673
# 38     CS 2800            Michael George      1101         96            4073
# 39    ECE 2100          Clifford Pollock       141         97             536
# 40    ECE 2200           David Delchamps       243         99             963
# 41   MATH 2930           Steven Strogatz       429         97            1658
# 42     CS 3410        Hakim Weatherspoon      2224        100            8598
# 43   INFO 4240            Phoebe Sengers       349        100            1246
# 44     CS 1110              Walker White      2681        100            8544
# 45     CS 2110               David Gries      2036        100           12742
# 46     CS 2800            Michael George      1058        100            6008
#
#     Avg_Response_Time  Enrolled  instructor_response  %Active semester  \
# 0                  22       259                   63       47     SP19
# 1                  39       417                   74       43     SP20
# 2                  49       543                   74       31     FA18
# 3                  40       162                   88       50     FA19
# 4                  26       135                   90       58     SP19
# 5                  24        37                   94       73     FA19
# 6                  20       419                   85       60     SP19
# 7                   9       618                   86       57     FA18
# 8                  39       506                   69       61     FA19
# 9                  40       430                   70       54     FA18
# 10                  7        28                   68       75     SP19
# 11                 44       482                   71       47     SP19
# 12                 22       238                   96       55     SP20
# 13                  3       721                   91       58     SP19
# 14                 22       145                   94       60     SP20
# 15                 10       716                   97       69     FA18
# 16                 64       216                   70      100     SP19
# 17                 52       379                   77       42     SP20
# 18                 10       716                   97       69     FA18
# 19                  4       590                   74       57     FA19
# 20                 44       482                   71       47     FA19
# 21                 11       404                   79       51     FA19
# 22                 20       405                   90       43     SP20
# 23                 41        42                   91       83     SP20
# 24                 25        36                   92       89     SP20
# 25                 44        44                   43       32     SP19
# 26                 40        84                   83       73     SP20
# 27                 16       197                   84       87     FA18
# 28                  8        90                   83       89     FA19
# 29                  1       667                   99       69     SP20
# 30                 37       396                   85       72     SP20
# 31                 16       473                   52       53     SP20
# 32                 11       404                   79       51     FA19
# 33                 38       145                   75       57     SP20
# 34                 43       403                   64       47     SP19
# 35                 14       242                   78       57     SP20
# 36                136        58                   54       84     FA18
# 37                 45        61                   87       84     FA19
# 38                 17       424                   78       66     FA19
# 39                 83        56                   89       59     SP20
# 40                 11        80                   94       68     SP20
# 41                 54       410                   59       43     FA19
# 42                 11       205                   87       90     SP19
# 43                 20       201                   95       68     FA18
# 44                 15       569                   84       73     FA17
# 45                  6       662                   90       61     SP18
# 46                  9       417                   77       63     FA18
#
#    department course_num
# 0        PHYS       2213
# 1        MATH       2930
# 2        MATH       1920
# 3        ORIE       2700
# 4         ECE       1210
# 5          CS       3220
# 6          CS       2800
# 7          CS       2110
# 8          CS       2850
# 9        MATH       2930
# 10       PHYS       2218
# 11       MATH       2940
# 12         CS       4700
# 13         CS       2110
# 14         CS       2043
# 15         CS       1110
# 16        ECE       3140
# 17       CHEM       2510
# 18         CS       1110
# 19         CS       2110
# 20       MATH       2940
# 21       PHYS       2213
# 22         CS       1110
# 23       ORIE       2700
# 24       MATH       2930
# 25       PHYS       1116
# 26         CS       4120
# 27         CS       3410
# 28         CS       2112
# 29         CS       2110
# 30         CS       2800
# 31       MATH       2940
# 32       PHYS       2213
# 33        MAE       2030
# 34       MATH       2930
# 35       PHYS       2213
# 36      ENGRI       1140
# 37        ECE       2720
# 38         CS       2800
# 39        ECE       2100
# 40        ECE       2200
# 41       MATH       2930
# 42         CS       3410
# 43       INFO       4240
# 44         CS       1110
# 45         CS       2110
# 46         CS       2800

# %% [markdown]
# ## ratemyprofessors.com
# * See "data_collect.ipymb"
# * We manually associate each course element of our piazza.csv database with the name of the professor who taught it that semester. We then manually aqcuire the URLs of the associated ratemyprofessors.com page of each of these professors and record them in the file "Rate_my_prof.txt". We then iterate through each URL in this file and scrape the necessary attributes for each review for the course we are looking for.
# * Because a review page for a professor includes many

# %%
ratings_data = pd.read_csv('rmp.csv')
ratings_data
# Out:
#           Professor Quality Difficulty Would Take Again            Date  \
# 0       Haym Hirsh      4.0        3.0              Yes  Dec 11th, 2020
# 1       Haym Hirsh      4.0        3.0              Yes  May 11th, 2020
# 2       Haym Hirsh      4.0        3.0              Yes   Apr 9th, 2020
# 3       Haym Hirsh      1.0        2.0               No  Dec 14th, 2019
# 4       Haym Hirsh     None       None             None            None
# ..              ...     ...        ...              ...             ...
# 664  Jose Martinez      5.0        4.0             None  Nov 11th, 2003
# 665  Jose Martinez      1.0        5.0             None   Nov 4th, 2003
# 666  Jose Martinez      4.5        4.0             None   Nov 3rd, 2003
# 667  Jose Martinez     None       None             None            None
# 668  Jose Martinez      1.0        3.0             None   Nov 3rd, 2003
#
#     Class taught
# 0         CS4700
# 1         CS4700
# 2         CS4700
# 3         CS4700
# 4           None
# ..           ...
# 664          475
# 665       ECE475
# 666       ECE475
# 667         None
# 668       ECE475
#
# [669 rows x 6 columns]

# %% [markdown]
# **Cleaning**
# * Some ratemyprofessors.com reviews are void because when they were scraped the ads on the page corrupted some of the observations (they weren't actual reviews), so we need to remove these observations. Every review is guaranteed to have a quality rating
# - Because the course names are listed as a single string, we need to split the department name and course number
# - We also need to convert columns that hold number values from string to int (eg, Difficulty)
# - Many reviews had typos in the course names (eg, "CS111" instead of "CS1110"). Also, there were some courses whos instructor had very few reviews. We resolved both of these issues at once my only including a review if at least 4 other reviews had the same course name. So, reviews for courses with 4 or fewer reviews were not included (to get a larger data sample and more accurate analysis) and reviews with misspelled course names were not included to reduce ambiguity (because there were far too many reviews to manually correct typos for).

# %%
# eliminate ads mistakenly scraped as reviews
ratings_data = ratings_data.copy()[ratings_data.Quality != 'None']

# split course department and number into separate columns with appropriate datatypes
n = []
d = []
dn = []
for index, row in ratings_data.iterrows():
    try:
        n.append(int((row['Class taught'])[-4:]))
        d.append(row['Class taught'][:-4])
        dn.append((row['Class taught'][:-4] +" " + (row['Class taught'])[-4:]).strip())
    except ValueError:
        n.append(0)
        d.append("-")
        dn.append("-")
ratings_data['course_number'] = n
ratings_data['department'] = d
ratings_data['Course#'] = dn

# convert columns to appropriate datatypes
ratings_data['Quality'] = (ratings_data['Quality']).astype(float).astype(int)
ratings_data['Difficulty'] = (ratings_data['Difficulty']).astype(float).astype(int)
ratings_data['course_number'] = (ratings_data['course_number']).astype(float).astype(int)
ratings_data = ratings_data.copy()[ratings_data.department != "-"]

# delete reviews of courses with too few reviews or reviews with misspelled course names
index = pd.Index(ratings_data['Class taught'])
counts = index.value_counts()
for i in range ((ratings_data['Class taught']).size):
    if counts[index[i]] < 5:
        ratings_data.iat[i,5] = None

# delete redundant column
ratings_data = ratings_data.dropna(how='all', subset=['Class taught'])

#add average ratings associated with the class and professor
ratings_data['avg_quality'] = ratings_data.groupby(['Course#'])['Quality'].transform('mean')
ratings_data['avg_difficulty'] = ratings_data.groupby(['Course#'])['Difficulty'].transform('mean')

ratings_data
# Out:
# C:\Users\amshi\Anaconda3\envs\info2950\lib\site-packages\pandas\core\computation\expressions.py:68: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   return op(a, b)
#              Professor  Quality  Difficulty Would Take Again            Date  \
# 0          Haym Hirsh         4           3              Yes  Dec 11th, 2020
# 1          Haym Hirsh         4           3              Yes  May 11th, 2020
# 2          Haym Hirsh         4           3              Yes   Apr 9th, 2020
# 3          Haym Hirsh         1           2               No  Dec 14th, 2019
# 5          Haym Hirsh         1           4               No  Nov 12th, 2019
# ..                 ...      ...         ...              ...             ...
# 642  Thomas Ruttledge         4           4              Yes  May 30th, 2018
# 652     Jose Martinez         4           4             None  Oct 26th, 2011
# 653     Jose Martinez         1           5             None  May 10th, 2010
# 654     Jose Martinez         2           5             None  May 13th, 2009
# 656     Jose Martinez         4           4             None  Mar 24th, 2009
#
#     Class taught  course_number department    Course#  avg_quality  \
# 0         CS4700           4700         CS    CS 4700     3.181818
# 1         CS4700           4700         CS    CS 4700     3.181818
# 2         CS4700           4700         CS    CS 4700     3.181818
# 3         CS4700           4700         CS    CS 4700     3.181818
# 5         CS4700           4700         CS    CS 4700     3.181818
# ..           ...            ...        ...        ...          ...
# 642     CHEM3580           3580       CHEM  CHEM 3580     2.454545
# 652      ECE2300           2300        ECE   ECE 2300     3.875000
# 653      ECE2300           2300        ECE   ECE 2300     3.875000
# 654      ECE2300           2300        ECE   ECE 2300     3.875000
# 656      ECE2300           2300        ECE   ECE 2300     3.875000
#
#      avg_difficulty
# 0          2.545455
# 1          2.545455
# 2          2.545455
# 3          2.545455
# 5          2.545455
# ..              ...
# 642        4.363636
# 652        2.812500
# 653        2.812500
# 654        2.812500
# 656        2.812500
#
# [326 rows x 11 columns]

# %% [markdown]
# ## Raw dataset descriptions
#
# * piazza_data
#     - Stores data collected from the statistics reports of each piazza course
#     - Observations: a course (courses can be repeated but not from the same semester, in other words, CS2110 is repeated three times, but each time the data is from a different semester
#     - Attributes:
#         + Course#: A string value of the department abbreviation and course number (eg, "PHYS 2213")
#         + Total_Q:
#         + %Response: percentage of questions that received a response
#         + #Contributions: total number of questions, answers, notes, and posts by all members
#         + Avg_Response_Time: average number of minutes it takes for a question to be answered
#         + Enrolled: number of students signed up to the course piazza
#         + instructor_response: percentage of questions answered by an instructor (the professor/lecturer or TA's)
#         + %Active: percentage of students enrolled who contributed on piazza
#         + Semester: A string containing the semester abbreviation and year abbreviation (eg, "SP19")
#         + department: a string value of the department of the course (eg, "PHYS")
#         + course_num: an integer value of the course number (eg, 2213)
#
#
# * ratings_data
#     - Stores data collected from the review pages of professors who have taught the courses that we collected piazza data for
#     - Observations: a professor
#     - Attributes:
#         + Name: the name of the professor as a string
#         + Quality: an integer rating from 1-5 of the quality of the professor's teaching
#         + Difficulty: an integer rating from 1-5 of the difficulty of the professor's course
#         + Would take again: a string value "Yes" or "No" based on whether the reviewer would take the course from that professor again
#         + Date: String timestamp of the review
#         + Class taught: a string value of the course the reviewer is basing their experience on with said professor (eg, "CS4700")
#         + course_number: integer value of the course number (eg, 4700)
#         + department: a string value of the department of the course (eg, "CS")
#         + Course #: string course name consistent with 'Course #' column in piazza_data

# %% [markdown]
# ## Final dataset creation

# %% [markdown]
# *See description in Final Project*

# %%
#merge datasets on professor name and course name
all_data = ratings_data.merge(piazza_data, how='inner',    right_on=['Course#','Professor'], left_on=['Course#','Professor'])

#drop redundant columns
all_data = all_data.drop(columns=['Class taught', 'department_y', 'course_num'])

#rename columns for consistency
all_data = all_data.rename(columns={"Professor": "instructor", "Quality": "quality", "Difficulty": "difficulty", 'Would Take Again': 'take_again', 'Date': 'timestamp', 'department_x':'department', 'Course#':'course_name', 'Total_Q': 'questions', '%Response':'%response','#Contributions':'contributions','Avg_Response_Time':'avg_response_time','Enrolled':'enrolled','%Active':'%active', 'instructor_response':'%instructor_response'})

all_data
# Out:
#             instructor  quality  difficulty take_again       timestamp  \
# 0          Haym Hirsh         4           3        Yes  Dec 11th, 2020
# 1          Haym Hirsh         4           3        Yes  May 11th, 2020
# 2          Haym Hirsh         4           3        Yes   Apr 9th, 2020
# 3          Haym Hirsh         1           2         No  Dec 14th, 2019
# 4          Haym Hirsh         1           4         No  Nov 12th, 2019
# ..                 ...      ...         ...        ...             ...
# 331  Thomas Ruttledge         5           5        Yes   Aug 9th, 2019
# 332  Thomas Ruttledge         3           4        Yes  May 28th, 2019
# 333  Thomas Ruttledge         1           5         No  Dec 20th, 2018
# 334  Thomas Ruttledge         1           4         No  Dec 19th, 2018
# 335  Thomas Ruttledge         2           5         No  Jun 19th, 2018
#
#      course_number department course_name  questions  %response  \
# 0             4700         CS     CS 4700        409         99
# 1             4700         CS     CS 4700        409         99
# 2             4700         CS     CS 4700        409         99
# 3             4700         CS     CS 4700        409         99
# 4             4700         CS     CS 4700        409         99
# ..             ...        ...         ...        ...        ...
# 331           2510       CHEM   CHEM 2510        426         99
# 332           2510       CHEM   CHEM 2510        426         99
# 333           2510       CHEM   CHEM 2510        426         99
# 334           2510       CHEM   CHEM 2510        426         99
# 335           2510       CHEM   CHEM 2510        426         99
#
#      contributions  avg_response_time  enrolled  %instructor_response  \
# 0             1875                 22       238                    96
# 1             1875                 22       238                    96
# 2             1875                 22       238                    96
# 3             1875                 22       238                    96
# 4             1875                 22       238                    96
# ..             ...                ...       ...                   ...
# 331           1665                 52       379                    77
# 332           1665                 52       379                    77
# 333           1665                 52       379                    77
# 334           1665                 52       379                    77
# 335           1665                 52       379                    77
#
#      %active semester
# 0         55     SP20
# 1         55     SP20
# 2         55     SP20
# 3         55     SP20
# 4         55     SP20
# ..       ...      ...
# 331       42     SP20
# 332       42     SP20
# 333       42     SP20
# 334       42     SP20
# 335       42     SP20
#
# [336 rows x 16 columns]

# %%
#write to csv file
import csv
all_data.to_csv('all_data.csv')
