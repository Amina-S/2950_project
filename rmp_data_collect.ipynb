# %%
import sys
import requests
import bs4 
import numpy as np
import pandas as pd
import os
import time
import csv

myfile = open("Rate_my_prof.txt") 
with open("rmp.csv", "w", newline = '') as csvfile:
    #open and initialize .csv
    writer = csv.writer(csvfile)
    columns = [("Name", "Quality", "Difficulty", "Would Take Again", "Date", "Class taught")]
    for data in columns:
            writer.writerow(data)
    
    #every ratemyprofs url
    for line in myfile:
        url = line
        url = url.rstrip("\n")
        url = url.strip('view-source:')
        page = requests.get(url)
        
        soup = bs4.BeautifulSoup(page.text, "html.parser")
        dataset = []
        ul      = soup.find('ul', {'class': 'RatingsList__RatingsUL-hn9one-1 kHITzZ'})
        print(url)
        
        #scrape data
        if ul is not None:
            for item in ul.findAll('li', recursive = False):

                if item is not None:
                    
                    date = "None"
                    quality = "None"
                    difficulty = "None"
                    would_take_again = "None"
                    course = "None"
                    
                    #prof name
                    name_class = soup.find("div", {"class": 'NameTitle__Name-dowf0z-0 cfjPUG'})
                    first_name = name_class.span.text
                    last_name_class = name_class.find("span", {"class": 'NameTitle__LastNameWrapper-dowf0z-2 glXOHH'})
                    last_name = last_name_class.text
                    name = first_name + " " + last_name
                  
                    #quality and difficulty ratings
                    q_d_up_class = item.find("div", {"class": 'RatingValues__StyledRatingValues-sc-6dc747-0 bJSTHc'})                    
                    if q_d_up_class is not None:
                        quality_and_difficulty = q_d_up_class.select('div[class*="RatingValues__RatingValue-sc"]')
                        q = str(quality_and_difficulty[0])
                        quality = float(q[-9:-6])
                        d = str(quality_and_difficulty[1])
                        difficulty = float(d[-9:-6])
                    
                    #would take again
                    would_take_again_up = item.find("div", {"class": 'CourseMeta__StyledCourseMeta-x344ms-0 dgqjDO'})                    
                    if would_take_again_up is not None:
                        would_take_again_list = would_take_again_up.select('div[class*="MetaItem__StyledMetaItem-"]')
                        if len(would_take_again_list) >2:
                            would_take_again = would_take_again_list[2].span.text
                    
                    #timestamp
                    time_course_up_class = item.find("div", {"class": 'RatingHeader__StyledHeader-sc-1dlkqw1-0 kiSEdA'})
                    print (time_course_up_class)
                    if time_course_up_class is not None:
                        time_up_list = time_course_up_class.select('div[class*="TimeStamp__StyledTimeStamp-sc-9q2r30-"]')
                        date = time_up_list[0].text
                        course_up_list = time_course_up_class.select('div[class*="RatingHeader__ClassInfoWrapper-sc-1dlkqw1-1 jxOApy"]')
                        #course_up_class = course_up_list[0].find("div",{"class": 'RatingHeader__StyledClass-sc-1dlkqw1-2 cElrQc'})
                        course_up_class = course_up_list[0].find("div",{"class": 'RatingHeader__StyledClass-sc-1dlkqw1-2 gxDIt'})

        
                        course = course_up_class.text
                        print(course)
                    
                    
                    dataset.append((name, quality, difficulty, would_take_again, date))
                    
            #write to dataset
            for data in dataset:
                writer.writerow(data)

            time.sleep(0.01)

myfile.close()
# Out:
# https://www.ratemyprofessors.com/ShowRatings.jsp?tid=2258736
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.ratemyprofessors.com/ShowRatings.jsp?tid=1705832
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.ratemyprofessors.com/ShowRatings.jsp?tid=261710
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1c45ac7ef825> in <module>
#      23         page = requests.get(url)
#      24
# ---> 25         soup = bs4.BeautifulSoup(page.text, "html.parser")
#      26         dataset = []
#      27         ul      = soup.find('ul', {'class': 'RatingsList__RatingsUL-hn9one-1 kHITzZ'})
#
# ~\Anaconda3\envs\info2950\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     343             self.reset()
#     344             try:
# --> 345                 self._feed()
#     346                 success = True
#     347                 break
#
# ~\Anaconda3\envs\info2950\lib\site-packages\bs4\__init__.py in _feed(self)
#     429         self.builder.reset()
#     430
# --> 431         self.builder.feed(self.markup)
#     432         # Close out any unfinished strings and close all the open tags.
#     433         self.endData()
#
# ~\Anaconda3\envs\info2950\lib\site-packages\bs4\builder\_htmlparser.py in feed(self, markup)
#     375         parser.soup = self.soup
#     376         try:
# --> 377             parser.feed(markup)
#     378             parser.close()
#     379         except HTMLParseError as e:
#
# ~\Anaconda3\envs\info2950\lib\html\parser.py in feed(self, data)
#     109         """
#     110         self.rawdata = self.rawdata + data
# --> 111         self.goahead(0)
#     112
#     113     def close(self):
#
# ~\Anaconda3\envs\info2950\lib\html\parser.py in goahead(self, end)
#     171                     k = self.parse_starttag(i)
#     172                 elif startswith("</", i):
# --> 173                     k = self.parse_endtag(i)
#     174                 elif startswith("<!--", i):
#     175                     k = self.parse_comment(i)
#
# ~\Anaconda3\envs\info2950\lib\html\parser.py in parse_endtag(self, i)
#     419                 return gtpos
#     420
# --> 421         self.handle_endtag(elem)
#     422         self.clear_cdata_mode()
#     423         return gtpos
#
# ~\Anaconda3\envs\info2950\lib\site-packages\bs4\builder\_htmlparser.py in handle_endtag(self, name, check_already_closed)
#     185             self.already_closed_empty_element.remove(name)
#     186         else:
# --> 187             self.soup.handle_endtag(name)
#     188
#     189     def handle_data(self, data):
#
# ~\Anaconda3\envs\info2950\lib\site-packages\bs4\__init__.py in handle_endtag(self, name, nsprefix)
#     708         #print("End tag: " + name)
#     709         self.endData()
# --> 710         self._popToTag(name, nsprefix)
#     711
#     712     def handle_data(self, data):
#
# ~\Anaconda3\envs\info2950\lib\site-packages\bs4\__init__.py in _popToTag(self, name, nsprefix, inclusivePop)
#     657                 if inclusivePop:
#     658                     most_recently_popped = self.popTag()
# --> 659                 break
#     660             most_recently_popped = self.popTag()
#     661
#
# KeyboardInterrupt:
